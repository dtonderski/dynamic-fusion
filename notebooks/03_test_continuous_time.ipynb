# %%
from torchvision.utils import save_image
from torchvision.io import read_image
from matplotlib import pyplot as plt

# %%
i_videos = [0, 1]

cont_vid = [read_image(f'../test/img{i}.png') for i in range(48)]

end_vid = [read_image(f'../test_video/img{i}.png') for i in range(48)]

# %%
y_start = 10
y_end = 30

plt.imshow(end_vid[0][0, y_start:y_end, 0:40])
plt.show()
plt.imshow(cont_vid[1][0, y_start:y_end, 0:40])
plt.show()
plt.imshow(end_vid[1][0, y_start:y_end, 0:40])
plt.show()
