# %%
import scipy
from matplotlib import pyplot as plt
import numpy as np

N_max = 15
N = np.random.randint(2, N_max)
N = 8

rng = np.random.default_rng(3)
values = rng.uniform(low=-0.6, high=0.6, size = (N))
plt.plot(values)

# %%
import scipy.interpolate


M = 1000
t_k = np.linspace(0,1, N)
t_m = np.linspace(0,1, M)

font = {'size'   : 14}

plt.rc('font', **font)


interp = scipy.interpolate.interp1d(t_k, values)
p = interp(t_m)
plt.plot(t_m, p, label='Linear interpolation', linewidth=4)

interp = scipy.interpolate.interp1d(t_k, values, kind='cubic')
p = interp(t_m)
plt.plot(t_m, p, '--', label='Bicubic interpolation', linewidth=4)

plt.plot(t_k, values, 'k.', label='Control point values', markersize = 15)
plt.xlabel('t')
plt.ylabel('Control value')
plt.legend()
plt.savefig('interpolation.png')

# %%
t_k
# Out:
# array([0.        , 0.14285714, 0.28571429, 0.42857143, 0.57142857,
#        0.71428571, 0.85714286, 1.        ])
